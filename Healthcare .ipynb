# %% [markdown]
# # Healthcare data analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\hplap\\OneDrive\\Desktop\\weekly task'

# %%
import pandas as pd
df = pd.read_csv(r"C:\\Users\\hplap\\OneDrive\\Desktop\\weekly task\Healthcare_dataset.csv")
print("Dataset loaded successfully")
# Out:
# Dataset loaded successfully

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# 1            2019-08-20   Samantha Davies                       Kim Inc
# 2            2022-09-22  Tiffany Mitchell                      Cook PLC
# 3            2020-11-18       Kevin Wells    Hernandez Rogers and Vang,
# 4            2022-09-19    Kathleen Hanna                   White-White
# ...                 ...               ...                           ...
# 55495        2020-08-16     Joshua Jarvis                Jones-Thompson
# 55496        2020-01-23   Taylor Sullivan                  Tucker-Moyer
# 55497        2020-07-13    Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 55498        2019-05-25    Kimberly Curry      Jackson Todd and Castro,
# 55499        2024-04-02     Dennis Warren                Henry Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0             Blue Cross    18856.281306          328         Urgent
# 1               Medicare    33643.327287          265      Emergency
# 2                  Aetna    27955.096079          205      Emergency
# 3               Medicare    37909.782410          450       Elective
# 4                  Aetna    14238.317814          458         Urgent
# ...                  ...             ...          ...            ...
# 55495         Blue Cross     2650.714952          417       Elective
# 55496              Cigna    31457.797307          316       Elective
# 55497   UnitedHealthcare    27620.764717          347         Urgent
# 55498           Medicare    32451.092358          321       Elective
# 55499              Aetna     4010.134172          448         Urgent
#
#       Discharge Date   Medication  Test Results
# 0         2024-02-02  Paracetamol        Normal
# 1         2019-08-26    Ibuprofen  Inconclusive
# 2         2022-10-07      Aspirin        Normal
# 3         2020-12-18    Ibuprofen      Abnormal
# 4         2022-10-09   Penicillin      Abnormal
# ...              ...          ...           ...
# 55495     2020-09-15   Penicillin      Abnormal
# 55496     2020-02-01      Aspirin        Normal
# 55497     2020-08-10    Ibuprofen      Abnormal
# 55498     2019-05-31    Ibuprofen      Abnormal
# 55499     2024-04-29    Ibuprofen      Abnormal
#
# [55500 rows x 15 columns]

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0    18856.281306          328         Urgent     2024-02-02  Paracetamol
# 1    33643.327287          265      Emergency     2019-08-26    Ibuprofen
# 2    27955.096079          205      Emergency     2022-10-07      Aspirin
# 3    37909.782410          450       Elective     2020-12-18    Ibuprofen
# 4    14238.317814          458         Urgent     2022-10-09   Penicillin
#
#    Test Results
# 0        Normal
# 1  Inconclusive
# 2        Normal
# 3      Abnormal
# 4      Abnormal

# %%
df.tail()
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission           Doctor                      Hospital  \
# 55495        2020-08-16    Joshua Jarvis                Jones-Thompson
# 55496        2020-01-23  Taylor Sullivan                  Tucker-Moyer
# 55497        2020-07-13   Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 55498        2019-05-25   Kimberly Curry      Jackson Todd and Castro,
# 55499        2024-04-02    Dennis Warren                Henry Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 55495         Blue Cross     2650.714952          417       Elective
# 55496              Cigna    31457.797307          316       Elective
# 55497   UnitedHealthcare    27620.764717          347         Urgent
# 55498           Medicare    32451.092358          321       Elective
# 55499              Aetna     4010.134172          448         Urgent
#
#       Discharge Date  Medication Test Results
# 55495     2020-09-15  Penicillin     Abnormal
# 55496     2020-02-01     Aspirin       Normal
# 55497     2020-08-10   Ibuprofen     Abnormal
# 55498     2019-05-31   Ibuprofen     Abnormal
# 55499     2024-04-29   Ibuprofen     Abnormal

# %%
df.sample()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 7315  KeviN REed   70  Female         O-            Cancer        2020-11-05
#
#             Doctor                  Hospital Insurance Provider  \
# 7315  Ruben Medina  and Johnston Chan, Miles           Medicare
#
#       Billing Amount  Room Number Admission Type Discharge Date  Medication  \
# 7315    17224.325716          136       Elective     2020-11-20  Penicillin
#
#      Test Results
# 7315     Abnormal

# %%
df.head(3)
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
#
#              Doctor         Hospital Insurance Provider  Billing Amount  \
# 0     Matthew Smith  Sons and Miller         Blue Cross    18856.281306
# 1   Samantha Davies          Kim Inc           Medicare    33643.327287
# 2  Tiffany Mitchell         Cook PLC              Aetna    27955.096079
#
#    Room Number Admission Type Discharge Date   Medication  Test Results
# 0          328         Urgent     2024-02-02  Paracetamol        Normal
# 1          265      Emergency     2019-08-26    Ibuprofen  Inconclusive
# 2          205      Emergency     2022-10-07      Aspirin        Normal

# %%
df.sample(5)
# Out:
#                  Name  Age  Gender Blood Type Medical Condition  \
# 30124  EMIly cAmpBelL   51    Male        AB+          Diabetes
# 10582  CHErYl FreemAn   65  Female         O+            Cancer
# 39013   cyNtHia ONeal   29  Female         A+          Diabetes
# 3968      liSa ingRaM   54  Female        AB+      Hypertension
# 32409   jennifer cArr   81    Male         A-         Arthritis
#
#       Date of Admission              Doctor                     Hospital  \
# 30124        2021-03-24  Michelle Rasmussen                 Ltd Reynolds
# 10582        2019-12-04     Christina Davis                Keller-Martin
# 39013        2022-10-08       Steven Brooks  and Myers Johnson Cummings,
# 3968         2021-01-25         Jose Curtis    and Hatfield Mann, Strong
# 32409        2020-10-21         Daisy Reyes                 Inc Gonzales
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 30124           Medicare    34363.993140          433       Elective
# 10582              Cigna    29392.009757          306       Elective
# 39013   UnitedHealthcare    24534.944036          359      Emergency
# 3968          Blue Cross    22690.598724          497       Elective
# 32409              Cigna    48829.645581          494      Emergency
#
#       Discharge Date   Medication  Test Results
# 30124     2021-03-28    Ibuprofen        Normal
# 10582     2019-12-27  Paracetamol      Abnormal
# 39013     2022-10-30  Paracetamol      Abnormal
# 3968      2021-02-05   Penicillin  Inconclusive
# 32409     2020-10-28      Aspirin        Normal

# %%
print("Dataset Shape:",df.shape)
print("Number of Rows:",df.shape[0])
print("Number of Columns:",df.shape[1])
print("Total Elements:",df.size)
# Out:
# Dataset Shape: (55500, 15)
# Number of Rows: 55500
# Number of Columns: 15
# Total Elements: 832500

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number             int64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  55500.000000    55500.000000  55500.000000
# mean      51.539459    25539.316097    301.134829
# std       19.602454    14211.454431    115.243069
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13241.224652    202.000000
# 50%       52.000000    25538.069376    302.000000
# 75%       68.000000    37820.508436    401.000000
# max       89.000000    52764.276736    500.000000

# %%
df.isnull()
# Out:
#         Name    Age  Gender  Blood Type  Medical Condition  Date of Admission  \
# 0      False  False   False       False              False              False
# 1      False  False   False       False              False              False
# 2      False  False   False       False              False              False
# 3      False  False   False       False              False              False
# 4      False  False   False       False              False              False
# ...      ...    ...     ...         ...                ...                ...
# 55495  False  False   False       False              False              False
# 55496  False  False   False       False              False              False
# 55497  False  False   False       False              False              False
# 55498  False  False   False       False              False              False
# 55499  False  False   False       False              False              False
#
#        Doctor  Hospital  Insurance Provider  Billing Amount  Room Number  \
# 0       False     False               False           False        False
# 1       False     False               False           False        False
# 2       False     False               False           False        False
# 3       False     False               False           False        False
# 4       False     False               False           False        False
# ...       ...       ...                 ...             ...          ...
# 55495   False     False               False           False        False
# 55496   False     False               False           False        False
# 55497   False     False               False           False        False
# 55498   False     False               False           False        False
# 55499   False     False               False           False        False
#
#        Admission Type  Discharge Date  Medication  Test Results
# 0               False           False       False         False
# 1               False           False       False         False
# 2               False           False       False         False
# 3               False           False       False         False
# 4               False           False       False         False
# ...               ...             ...         ...           ...
# 55495           False           False       False         False
# 55496           False           False       False         False
# 55497           False           False       False         False
# 55498           False           False       False         False
# 55499           False           False       False         False
#
# [55500 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
	df.dropna()
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# 1            2019-08-20   Samantha Davies                       Kim Inc
# 2            2022-09-22  Tiffany Mitchell                      Cook PLC
# 3            2020-11-18       Kevin Wells    Hernandez Rogers and Vang,
# 4            2022-09-19    Kathleen Hanna                   White-White
# ...                 ...               ...                           ...
# 55495        2020-08-16     Joshua Jarvis                Jones-Thompson
# 55496        2020-01-23   Taylor Sullivan                  Tucker-Moyer
# 55497        2020-07-13    Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 55498        2019-05-25    Kimberly Curry      Jackson Todd and Castro,
# 55499        2024-04-02     Dennis Warren                Henry Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0             Blue Cross    18856.281306          328         Urgent
# 1               Medicare    33643.327287          265      Emergency
# 2                  Aetna    27955.096079          205      Emergency
# 3               Medicare    37909.782410          450       Elective
# 4                  Aetna    14238.317814          458         Urgent
# ...                  ...             ...          ...            ...
# 55495         Blue Cross     2650.714952          417       Elective
# 55496              Cigna    31457.797307          316       Elective
# 55497   UnitedHealthcare    27620.764717          347         Urgent
# 55498           Medicare    32451.092358          321       Elective
# 55499              Aetna     4010.134172          448         Urgent
#
#       Discharge Date   Medication  Test Results
# 0         2024-02-02  Paracetamol        Normal
# 1         2019-08-26    Ibuprofen  Inconclusive
# 2         2022-10-07      Aspirin        Normal
# 3         2020-12-18    Ibuprofen      Abnormal
# 4         2022-10-09   Penicillin      Abnormal
# ...              ...          ...           ...
# 55495     2020-09-15   Penicillin      Abnormal
# 55496     2020-02-01      Aspirin        Normal
# 55497     2020-08-10    Ibuprofen      Abnormal
# 55498     2019-05-31    Ibuprofen      Abnormal
# 55499     2024-04-29    Ibuprofen      Abnormal
#
# [55500 rows x 15 columns]

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 55495    False
# 55496    False
# 55497    False
# 55498    False
# 55499    False
# Length: 55500, dtype: bool

# %%
df.drop_duplicates()
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# 1            2019-08-20   Samantha Davies                       Kim Inc
# 2            2022-09-22  Tiffany Mitchell                      Cook PLC
# 3            2020-11-18       Kevin Wells    Hernandez Rogers and Vang,
# 4            2022-09-19    Kathleen Hanna                   White-White
# ...                 ...               ...                           ...
# 55495        2020-08-16     Joshua Jarvis                Jones-Thompson
# 55496        2020-01-23   Taylor Sullivan                  Tucker-Moyer
# 55497        2020-07-13    Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 55498        2019-05-25    Kimberly Curry      Jackson Todd and Castro,
# 55499        2024-04-02     Dennis Warren                Henry Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0             Blue Cross    18856.281306          328         Urgent
# 1               Medicare    33643.327287          265      Emergency
# 2                  Aetna    27955.096079          205      Emergency
# 3               Medicare    37909.782410          450       Elective
# 4                  Aetna    14238.317814          458         Urgent
# ...                  ...             ...          ...            ...
# 55495         Blue Cross     2650.714952          417       Elective
# 55496              Cigna    31457.797307          316       Elective
# 55497   UnitedHealthcare    27620.764717          347         Urgent
# 55498           Medicare    32451.092358          321       Elective
# 55499              Aetna     4010.134172          448         Urgent
#
#       Discharge Date   Medication  Test Results
# 0         2024-02-02  Paracetamol        Normal
# 1         2019-08-26    Ibuprofen  Inconclusive
# 2         2022-10-07      Aspirin        Normal
# 3         2020-12-18    Ibuprofen      Abnormal
# 4         2022-10-09   Penicillin      Abnormal
# ...              ...          ...           ...
# 55495     2020-09-15   Penicillin      Abnormal
# 55496     2020-02-01      Aspirin        Normal
# 55497     2020-08-10    Ibuprofen      Abnormal
# 55498     2019-05-31    Ibuprofen      Abnormal
# 55499     2024-04-29    Ibuprofen      Abnormal
#
# [54966 rows x 15 columns]

# %%
pd.to_datetime(df['Discharge Date'])
# Out:
# 0       2024-02-02
# 1       2019-08-26
# 2       2022-10-07
# 3       2020-12-18
# 4       2022-10-09
#            ...
# 55495   2020-09-15
# 55496   2020-02-01
# 55497   2020-08-10
# 55498   2019-05-31
# 55499   2024-04-29
# Name: Discharge Date, Length: 55500, dtype: datetime64[ns]

# %%
df["Age"]=pd.to_numeric(df["Age"])

# %%
text_columns = ["Name","Age","Blood Type"]

for column in text_columns:
    df[column]=(
        df[column]
        .astype(str)
        .str.strip()
        .str.title()
    )

# %%
for column in text_columns:
    print("\n",column)
    print(df[column].unique())
# Out:
#  Name
# ['Bobby Jackson' 'Leslie Terry' 'Danny Smith' ... 'Lisa Simpson'
#  'Roger Farrell' 'Katherine Webster']
#
#  Age
# ['30' '62' '76' '28' '43' '36' '21' '20' '82' '58' '72' '38' '75' '68'
#  '44' '46' '63' '34' '67' '48' '59' '73' '51' '23' '78' '25' '33' '26'
#  '70' '57' '74' '81' '49' '65' '31' '22' '77' '42' '24' '84' '55' '40'
#  '83' '18' '27' '19' '29' '61' '80' '60' '35' '79' '53' '69' '47' '85'
#  '52' '37' '50' '32' '54' '45' '66' '39' '56' '64' '71' '41' '88' '17'
#  '87' '86' '15' '16' '13' '14' '89']
#
#  Blood Type
# ['B-' 'A+' 'A-' 'O+' 'Ab+' 'Ab-' 'B+' 'O-']

# %%
for column in text_columns:
    print("\n",column)
    print(df[column].value_counts())
# Out:
#  Name
# Name
# Michael Williams    24
# Michael Smith       23
# Robert Smith        22
# James Brown         19
# James Smith         18
#                     ..
# Dana Collins         1
# Cameron Williams     1
# Leslie Frederick     1
# Victor Jackson       1
# Terry Chavez         1
# Name: count, Length: 40235, dtype: int64
#
#  Age
# Age
# 38    897
# 37    893
# 57    887
# 80    864
# 34    864
#      ...
# 88     25
# 16     24
# 14     18
# 13     14
# 89      8
# Name: count, Length: 77, dtype: int64
#
#  Blood Type
# Blood Type
# A-     6969
# A+     6956
# Ab+    6947
# Ab-    6945
# B+     6945
# B-     6944
# O+     6917
# O-     6877
# Name: count, dtype: int64

# %%
df["Age"].value_counts()
# Out:
# Age
# 38    897
# 37    893
# 57    887
# 80    864
# 34    864
#      ...
# 88     25
# 16     24
# 14     18
# 13     14
# 89      8
# Name: count, Length: 77, dtype: int64

# %%
df["Admission Type"].unique()
# Out:
# array(['Urgent', 'Emergency', 'Elective'], dtype=object)

# %%
numerical_features = [
    "Age",
    "Room Number",
    "Discharge Date"
    
]
df[numerical_features].describe()
# Out:
#         Room Number
# count  55500.000000
# mean     301.134829
# std      115.243069
# min      101.000000
# 25%      202.000000
# 50%      302.000000
# 75%      401.000000
# max      500.000000

# %%
category= (
    df.groupby("Age")["Discharge Date"]
        .sum()
        .sort_values(ascending=False)
)

category
# Out:
# Age
# 86    2024-05-222022-07-152021-07-012022-06-272023-0...
# 61    2024-03-262020-10-032020-07-222019-09-072023-0...
# 30    2024-02-022020-02-102024-04-222020-10-212022-0...
# 51    2024-01-192020-07-202021-12-302020-06-212019-0...
# 64    2024-01-152022-08-072019-09-062020-11-202021-0...
#                             ...
# 62    2019-08-262019-10-152019-05-312024-02-192023-1...
# 47    2019-08-052019-07-012021-08-062022-11-232021-0...
# 77    2019-07-292020-08-052022-08-072021-10-092024-0...
# 42    2019-07-052024-02-032021-05-292021-08-052023-0...
# 15    2019-07-012020-08-092019-12-012023-03-162024-0...
# Name: Discharge Date, Length: 77, dtype: object

# %%
df.groupby("Medical Condition")["Billing Amount"].mean()
# Out:
# Medical Condition
# Arthritis       25497.327056
# Asthma          25635.249359
# Cancer          25161.792707
# Diabetes        25638.405577
# Hypertension    25497.095761
# Obesity         25805.971259
# Name: Billing Amount, dtype: float64

# %%
df.groupby("Medical Condition")["Billing Amount"].agg(
    ["mean","median","min","max","std"]
)
# Out:
#                            mean        median          min           max  \
# Medical Condition
# Arthritis          25497.327056  25581.763549 -1129.997176  52170.036854
# Asthma             25635.249359  25661.872824 -1520.420555  52181.837792
# Cancer             25161.792707  24910.980640 -2008.492140  52373.032374
# Diabetes           25638.405577  25621.077269 -1316.618581  52211.852966
# Hypertension       25497.095761  25275.670593 -1660.009373  52764.276736
# Obesity            25805.971259  26129.997134 -1310.272895  52024.726443
#
#                             std
# Medical Condition
# Arthritis          14276.529904
# Asthma             14241.677464
# Cancer             14200.271700
# Diabetes           14159.524315
# Hypertension       14305.400942
# Obesity            14079.526507

# %%
df["Age"].min()
# Out:
# '13'

# %%
df["Age"].max()
# Out:
# '89'

# %%
df["Room Number"].quantile([0.25,0.50,0.75])
# Out:
# 0.25    202.0
# 0.50    302.0
# 0.75    401.0
# Name: Room Number, dtype: float64

# %%
df["Gender"] = df["Gender"].str.strip()
df["Medical Condition"] = df["Medical Condition"].str.strip()
df["Admission Type"] = df["Admission Type"].str.strip()
df["Insurance Provider"] = df["Insurance Provider"].str.strip()

# %%
df["Gender"] = df["Gender"].str.title()
df["Medical Condition"] = df["Medical Condition"].str.title()
df["Admission Type"] = df["Admission Type"].str.title()
df["Insurance Provider"] = df["Insurance Provider"].str.title()

# %%
print(df["Gender"].unique())
print(df["Medical Condition"].unique())
print(df["Admission Type"].unique())
print(df["Insurance Provider"].unique())
# Out:
# ['Male' 'Female']
# ['Cancer' 'Obesity' 'Diabetes' 'Asthma' 'Hypertension' 'Arthritis']
# ['Urgent' 'Emergency' 'Elective']
# ['Blue Cross' 'Medicare' 'Aetna' 'Unitedhealthcare' 'Cigna']

# %%
df[
    (df["Room Number"]>60) &
    (df["Admission Type"] == "Emergency")
    ]
# Out:
#                      Name Age  Gender Blood Type Medical Condition  \
# 1            Leslie Terry  62    Male         A+           Obesity
# 2             Danny Smith  76  Female         A-           Obesity
# 6          Edward Edwards  21  Female        Ab-          Diabetes
# 7      Christina Martinez  20  Female         A+            Cancer
# 12          Connor Hansen  75  Female         A+          Diabetes
# ...                   ...  ..     ...        ...               ...
# 55490    Stephanie Oliver  82    Male         B-            Cancer
# 55491       Linda Griffin  47  Female         O+           Obesity
# 55492    Lauren Mccormick  51    Male         O+         Arthritis
# 55493        Gloria Bowen  57  Female         B-         Arthritis
# 55494       Jessica White  67    Male         O+         Arthritis
#
#       Date of Admission            Doctor                     Hospital  \
# 1            2019-08-20   Samantha Davies                      Kim Inc
# 2            2022-09-22  Tiffany Mitchell                     Cook PLC
# 6            2020-11-03       Kelly Olson              Group Middleton
# 7            2021-12-28    Suzanne Thomas  Powell Robinson and Valdez,
# 12           2019-12-12  Kenneth Fletcher    Powers Miller, and Flores
# ...                 ...               ...                          ...
# 55490        2022-01-10      Gary Leblanc                    Group Lee
# 55491        2020-06-21    Danielle Davis     and King Jordan Johnson,
# 55492        2020-12-06      Kevin Flores                  Inc Barnett
# 55493        2022-07-23    Lucas Thompson               Group Gonzalez
# 55494        2023-12-11      Jesus Jordan                Miller-Harris
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 1               Medicare    33643.327287          265      Emergency
# 2                  Aetna    27955.096079          205      Emergency
# 6               Medicare    19580.872345          389      Emergency
# 7                  Cigna    45820.462722          277      Emergency
# 12                 Cigna    43282.283358          134      Emergency
# ...                  ...             ...          ...            ...
# 55490              Cigna    17350.543524          381      Emergency
# 55491              Aetna    15715.551079          310      Emergency
# 55492              Cigna     2588.150832          289      Emergency
# 55493           Medicare     3954.853764          463      Emergency
# 55494           Medicare    42535.301234          378      Emergency
#
#       Discharge Date   Medication  Test Results
# 1         2019-08-26    Ibuprofen  Inconclusive
# 2         2022-10-07      Aspirin        Normal
# 6         2020-11-15  Paracetamol  Inconclusive
# 7         2022-01-07  Paracetamol  Inconclusive
# 12        2019-12-28   Penicillin      Abnormal
# ...              ...          ...           ...
# 55490     2022-01-21   Penicillin      Abnormal
# 55491     2020-06-25      Lipitor      Abnormal
# 55492     2020-12-12  Paracetamol        Normal
# 55493     2022-08-18      Aspirin      Abnormal
# 55494     2024-01-04    Ibuprofen        Normal
#
# [18269 rows x 15 columns]

# %%
df.sort_values("Billing Amount",ascending=False)
# Out:
#                    Name Age  Gender Blood Type Medical Condition  \
# 36349     Todd Carrillo  51  Female         A+      Hypertension
# 51313       Karen Kline  74  Female        Ab+            Cancer
# 34613       Karen Kline  79  Female        Ab+            Cancer
# 5735     David Sandoval  22    Male        Ab-      Hypertension
# 7088   Kathryn Gonzales  18  Female         O+          Diabetes
# ...                 ...  ..     ...        ...               ...
# 29484      Terry Wilson  39    Male         O-          Diabetes
# 44040    Joseph Robbins  71    Male         O-      Hypertension
# 42621         John Hahn  80    Male         O-            Asthma
# 48659       Emma Savage  57    Male        Ab+      Hypertension
# 47589        James Luna  64  Female        Ab-            Cancer
#
#       Date of Admission             Doctor                     Hospital  \
# 36349        2023-09-08   Kathleen Griffin                Griffin Group
# 51313        2021-06-19  Dr. Joseph Gordon             Hernandez-Morton
# 34613        2021-06-19  Dr. Joseph Gordon             Hernandez-Morton
# 5735         2019-11-02       Taylor Novak              Sons and Bailey
# 7088         2020-08-11      Kristin Clark                   Miller Ltd
# ...                 ...                ...                          ...
# 29484        2024-02-19        Diana Smith  Medina and Elliott Stewart,
# 44040        2024-02-10   Stacey Davenport                   Vaughn PLC
# 42621        2024-02-24         Mark Hines                   Ltd Wilson
# 48659        2021-09-05      Maria Johnson                Armstrong LLC
# 47589        2022-09-22        Todd Becker                 Juarez-Clark
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 36349         Blue Cross    52764.276736          209       Elective
# 51313   Unitedhealthcare    52373.032374          181         Urgent
# 34613   Unitedhealthcare    52373.032374          181         Urgent
# 5735          Blue Cross    52271.663747          228      Emergency
# 7088               Aetna    52211.852966          383         Urgent
# ...                  ...             ...          ...            ...
# 29484              Aetna    -1316.618581          491      Emergency
# 44040   Unitedhealthcare    -1428.843941          205         Urgent
# 42621              Cigna    -1520.420555          403       Elective
# 48659         Blue Cross    -1660.009373          193       Elective
# 47589              Aetna    -2008.492140          162         Urgent
#
#       Discharge Date   Medication  Test Results
# 36349     2023-10-04    Ibuprofen        Normal
# 51313     2021-07-03   Penicillin  Inconclusive
# 34613     2021-07-03   Penicillin  Inconclusive
# 5735      2019-11-11    Ibuprofen        Normal
# 7088      2020-08-12  Paracetamol  Inconclusive
# ...              ...          ...           ...
# 29484     2024-03-20  Paracetamol  Inconclusive
# 44040     2024-02-29    Ibuprofen      Abnormal
# 42621     2024-03-14      Lipitor      Abnormal
# 48659     2021-10-02   Penicillin        Normal
# 47589     2022-10-20    Ibuprofen      Abnormal
#
# [55500 rows x 15 columns]

# %%
condition_summary = (
    df.groupby("Medical Condition")["Billing Amount"]
    .mean()
    .reset_index()
)

condition_summary
# Out:
#   Medical Condition  Billing Amount
# 0         Arthritis    25497.327056
# 1            Asthma    25635.249359
# 2            Cancer    25161.792707
# 3          Diabetes    25638.405577
# 4      Hypertension    25497.095761
# 5           Obesity    25805.971259

# %%
df[["Age","Billing Amount","Room Number"]].corr()
# Out:
#                      Age  Billing Amount  Room Number
# Age             1.000000       -0.003832    -0.000720
# Billing Amount -0.003832        1.000000    -0.002943
# Room Number    -0.000720       -0.002943     1.000000

# %%
df["Length of Stay"] =(
    pd.to_datetime(df["Discharge Date"]) -
    pd.to_datetime(df["Date of Admission"])
).dt.days

df[["Date of Admission","Discharge Date","Length of Stay"]].head()
# Out:
#   Date of Admission Discharge Date  Length of Stay
# 0        2024-01-31     2024-02-02               2
# 1        2019-08-20     2019-08-26               6
# 2        2022-09-22     2022-10-07              15
# 3        2020-11-18     2020-12-18              30
# 4        2022-09-19     2022-10-09              20

# %%
df["Admission Year"] = pd.to_datetime(
    df["Date of Admission"]
).dt.year

df[["Date of Admission", "Admission Year"]].head()
# Out:
#   Date of Admission  Admission Year
# 0        2024-01-31            2024
# 1        2019-08-20            2019
# 2        2022-09-22            2022
# 3        2020-11-18            2020
# 4        2022-09-19            2022

# %%
df["Admission Month"] = pd.to_datetime(
    df["Date of Admission"]
).dt.month

df[["Date of Admission", "Admission Month"]].head()
# Out:
#   Date of Admission  Admission Month
# 0        2024-01-31                1
# 1        2019-08-20                8
# 2        2022-09-22                9
# 3        2020-11-18               11
# 4        2022-09-19                9

# %%
df.groupby("Admission Year")["Billing Amount"].mean()
# Out:
# Admission Year
# 2019    25700.463671
# 2020    25392.254250
# 2021    25629.483239
# 2022    25513.509808
# 2023    25573.848469
# 2024    25380.295013
# Name: Billing Amount, dtype: float64

# %%
monthly_admissions =(

df.groupby("Admission Month")["Name"]
    .count()
    .reset_index()
)

monthly_admissions
# Out:
#     Admission Month  Name
# 0                 1  4692
# 1                 2  4255
# 2                 3  4672
# 3                 4  4518
# 4                 5  4599
# 5                 6  4699
# 6                 7  4812
# 7                 8  4832
# 8                 9  4546
# 9                10  4678
# 10               11  4548
# 11               12  4649

# %%
plt.figure(figsize=(9,5))

sns.lineplot(
    data=monthly_admissions,
    x="Admission Month",
    y="Name",
    marker="o"
)

plt.title("Monthly Number of Admissions")
plt.xlabel("Admission Month")
plt.ylabel("Number of Admissions")

plt.show()
